# %%
pip install transformers==4.41.2 peft==0.11.1 accelerate==0.31.0
pip install datasets==2.19.2 bert-score==0.3.13 rouge-score==0.1.2
pip install bitsandbytes==0.43.1

# %%
# ══ سلول ۲: بررسی GPU ══
import torch
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB")

# %%
# ══ سلول ۳: اتصال Google Drive ══
from google.colab import drive
drive.mount('/content/drive')

# %%
# ══ سلول ۴: clone پروژه (یا آپلود) ══
import os
PROJECT_DIR = '/content/drive/MyDrive/arasum-offline'
os.makedirs(PROJECT_DIR, exist_ok=True)
# !git clone https://github.com/YOUR_REPO/arabic-offline-summarizer.git {PROJECT_DIR}
# یا فایل‌ها را آپلود کنید

# ══ سلول ۵: نصب پکیج پروژه ══
# %cd {PROJECT_DIR}
# !pip install -e .

# ══ سلول ۶: آماده‌سازی دیتاست ══
# !python scripts/training/prepare_dataset.py --source xlsum_arabic

# ══ سلول ۷: Smoke Test ══
# !python scripts/training/finetune.py --smoke-test

# ══ سلول ۸: آموزش کامل ══
# !python scripts/training/finetune.py \\
#     --output-dir /content/drive/MyDrive/arasum-models/ \\
#     --epochs 3

# ══ سلول ۹: ارزیابی ══
# !python scripts/evaluation/evaluate_finetuned.py \\
#     --model-path /content/drive/MyDrive/arasum-models/ \\
#     --output-dir /content/drive/MyDrive/arasum-reports/
